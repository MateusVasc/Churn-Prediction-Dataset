# %%
# importar os pacotes necessários.
import pandas as pd
import plotly.express as px

# importar os dados e indexar a  coluna id no df.
df = pd.read_csv("https://raw.githubusercontent.com/victor-ferreira/dataset/main/WA_Fn-UseC_-Telco-Customer-Churn.csv",
                 index_col='customerID')

df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
freq = df['TotalCharges'].value_counts() 
print(freq)
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
df = df.drop(df.loc[df['TotalCharges'] == ' '].index)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
df["TotalCharges"] = df["TotalCharges"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
fig = px.histogram(df, x="gender", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="5d2227ba-fc0e-499a-b87a-5bbf05fcc1fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d2227ba-fc0e-499a-b87a-5bbf05fcc1fe")) {                    Plotly.newPlot(                        "5d2227ba-fc0e-499a-b87a-5bbf05fcc1fe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>gender=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Male","
# ...

# %%
fig = px.histogram(df, x="Dependents", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="8afb3542-5931-4bff-a23e-919024e2f469" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8afb3542-5931-4bff-a23e-919024e2f469")) {                    Plotly.newPlot(                        "8afb3542-5931-4bff-a23e-919024e2f469",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>Dependents=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","No","No","No","Yes","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","No","No","No","Y
# ...

# %%
fig = px.histogram(df, x="PhoneService", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="7aae979d-e3ed-451f-8992-ad233cabd6b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aae979d-e3ed-451f-8992-ad233cabd6b3")) {                    Plotly.newPlot(                        "7aae979d-e3ed-451f-8992-ad233cabd6b3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>PhoneService=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes
# ...

# %%
fig = px.histogram(df, x="MultipleLines", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="ef6a13ef-3595-4cca-aa2d-a001e41b9ba2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef6a13ef-3595-4cca-aa2d-a001e41b9ba2")) {                    Plotly.newPlot(                        "ef6a13ef-3595-4cca-aa2d-a001e41b9ba2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>MultipleLines=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No phone service","No","No phone service","Yes","No phone service","No","No","No","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","No","No","Yes","No",
# ...

# %%
fig = px.histogram(df, x="InternetService", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="00f537c1-ddd5-4732-9835-49432c355f9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00f537c1-ddd5-4732-9835-49432c355f9a")) {                    Plotly.newPlot(                        "00f537c1-ddd5-4732-9835-49432c355f9a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>InternetService=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["DSL","DSL","DSL","Fiber optic","DSL","DSL","DSL","No","Fiber optic","Fiber optic","Fiber optic","No","Fiber optic","Fiber optic","No","DSL","DSL","DSL","DSL","Fiber optic","Fibe
# ...

# %%
fig = px.histogram(df, x="OnlineSecurity", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="481d731d-fe2c-413c-b61c-6d624a022519" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("481d731d-fe2c-413c-b61c-6d624a022519")) {                    Plotly.newPlot(                        "481d731d-fe2c-413c-b61c-6d624a022519",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>OnlineSecurity=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No","Yes","Yes","No","Yes","Yes","Yes","No internet service","No","Yes","Yes","No internet service","Yes","No","No internet service","No","Yes","Yes","Yes","Yes","No","Yes","No i
# ...

# %%
fig = px.histogram(df, x="OnlineBackup", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="65dffb3c-af4c-47e5-abd6-671e0db0f549" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65dffb3c-af4c-47e5-abd6-671e0db0f549")) {                    Plotly.newPlot(                        "65dffb3c-af4c-47e5-abd6-671e0db0f549",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>OnlineBackup=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Yes","No","No","Yes","No","Yes","No","No internet service","No","No","Yes","No internet service","No","Yes","No internet service","Yes","Yes","Yes","Yes","Yes","No","Yes","No inter
# ...

# %%
fig = px.histogram(df, x="DeviceProtection", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="d823d5ad-f0ca-480c-b91d-2e75f41bb610" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d823d5ad-f0ca-480c-b91d-2e75f41bb610")) {                    Plotly.newPlot(                        "d823d5ad-f0ca-480c-b91d-2e75f41bb610",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>DeviceProtection=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No","Yes","Yes","No","No","No","No","No internet service","Yes","Yes","Yes","No internet service","Yes","Yes","No internet service","No","No","No","Yes","Yes","Yes","Yes","No i
# ...

# %%
fig = px.histogram(df, x="TechSupport", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="fc05fc4d-2c2e-4f7b-afc2-2f8fa24fbc9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc05fc4d-2c2e-4f7b-afc2-2f8fa24fbc9b")) {                    Plotly.newPlot(                        "fc05fc4d-2c2e-4f7b-afc2-2f8fa24fbc9b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>TechSupport=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["No","No","Yes","No","No","No","No","No internet service","No","Yes","Yes","No internet service","No","No","No internet service","Yes","Yes","No","Yes","Yes","No","Yes","No internet 
# ...

# %%
fig = px.histogram(df, x="Contract", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="e043adce-b47a-431d-8c02-adf3ce5dafc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e043adce-b47a-431d-8c02-adf3ce5dafc3")) {                    Plotly.newPlot(                        "e043adce-b47a-431d-8c02-adf3ce5dafc3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>Contract=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Month-to-month","One year","One year","Month-to-month","Month-to-month","One year","Month-to-month","Two year","One year","Month-to-month","Two year","One year","Two year","Month-to-mo
# ...

# %%
fig = px.histogram(df, x="PaperlessBilling", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="370f60ab-3aad-4187-8c59-a182f0be4ff0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("370f60ab-3aad-4187-8c59-a182f0be4ff0")) {                    Plotly.newPlot(                        "370f60ab-3aad-4187-8c59-a182f0be4ff0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>PaperlessBilling=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Yes","No","No","Yes","No","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","N
# ...

# %%
fig = px.histogram(df, x="PaymentMethod", color="Churn", text_auto=True)
fig.show()
# Out:
# <div>                            <div id="6d413d85-808a-47ac-b207-ae990336a09b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d413d85-808a-47ac-b207-ae990336a09b")) {                    Plotly.newPlot(                        "6d413d85-808a-47ac-b207-ae990336a09b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>PaymentMethod=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Electronic check","Mailed check","Bank transfer (automatic)","Credit card (automatic)","Mailed check","Bank transfer (automatic)","Mailed check","Credit card (automatic)","Credit 
# ...
